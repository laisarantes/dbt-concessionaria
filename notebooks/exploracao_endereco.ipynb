# %%
import os
import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %%
load_dotenv()
# Out:
# True

# %%
engine = create_engine(
    f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}"
)

# %%
df_endereco = pd.read_sql("SELECT * FROM raw.endereco;", engine)

# %%
df_endereco.head()
# Out:
#    endereco_id               rua numero      bairro     cidade estado  \
# 0            1   Rua das Flores     101      Centro  Fortaleza     CE
# 1            2    RUA DAS FLORES    101      centro  FORTALEZA     ce
# 2            3     Av. Beira Mar   2500   Meireles   Fortaleza  Ceará
# 3            4      Av Beira Mar   2500    Meireles  fortaleza     CE
# 4            5             Rua A     12     Aldeota  Fortaleza     CE
#
#          cep
# 0  60010-000
# 1   60010000
# 2  60165-121
# 3   60165121
# 4  60150-100

# %%
df_endereco.tail()
# Out:
#     endereco_id                 rua numero       bairro     cidade estado  \
# 55           56       Rua Principal      1  industrial   Horizonte     ce
# 56           57  Rua XV de Novembro    750       Centro  Fortaleza     CE
# 57           58     Rua XV Novembro    750       Centro  FORTALEZA     CE
# 58           59   Rua das Palmeiras    340        Cocó   Fortaleza     CE
# 59           60   Rua das Palmeiras    340         Coco  Fortaleza     ce
#
#           cep
# 55   62880000
# 56
# 57        NaN
# 58  60192-150
# 59   60192150

# %%
df_endereco.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   endereco_id  60 non-null     int64
#  1   rua          60 non-null     str
#  2   numero       56 non-null     str
#  3   bairro       60 non-null     str
#  4   cidade       60 non-null     str
#  5   estado       60 non-null     str
#  6   cep          54 non-null     str
# dtypes: int64(1), str(6)
# memory usage: 3.4 KB

# %%
df_endereco.shape
# Out:
# (60, 7)

# %%
pd.read_sql("SELECT DISTINCT * FROM raw.endereco;", engine)
# Out:
#     endereco_id                   rua numero          bairro  \
# 0            45          Rua sem nome                 Centro
# 1            48     Trav. das Acacias     45  Jardim America
# 2            42      Av Santos Dumont   3500         aldeota
# 3            40                 Rua D     15          Centro
# 4             4          Av Beira Mar   2500        Meireles
# 5            26         Rua Principal      1     industrial
# 6            32        RUA DAS FLORES    101          centro
# 7            37                 Rua B    34A          Papicu
# 8            59     Rua das Palmeiras    340           Cocó
# 9            43   Rua José de Alencar     88         Benfica
# 10           55         Rua Principal     01      Industrial
# 11           41     Av. Santos Dumont   3500         Aldeota
# 12           14   Rua Jose de Alencar     88         BENFICA
# 13           28       Rua XV Novembro    750          Centro
# 14           25         Rua Principal     01      Industrial
# 15           23            Av. Brasil    900          Centro
# 16           57    Rua XV de Novembro    750          Centro
# 17           24             Av Brasil    900          Centro
# 18           17  Travessa das Acácias     45  Jardim América
# 19           50      Rua Padre Cicero    150          centro
# 20           27    Rua XV de Novembro    750          Centro
# 21           11     Av. Santos Dumont   3500         Aldeota
# 22           58       Rua XV Novembro    750          Centro
# 23           49      Rua Padre Cícero    150          Centro
# 24           30     Rua das Palmeiras    340            Coco
# 25           12      Av Santos Dumont   3500         aldeota
# 26            2        RUA DAS FLORES    101          centro
# 27           20      Rua Padre Cicero    150          centro
# 28            6                 Rua A    NaN         Aldeota
# 29            1       Rua das Flores     101          Centro
# 30           15          Rua sem nome                 Centro
# 31           22         Rua Sao Paulo    500          CENTRO
# 32            3         Av. Beira Mar   2500       Meireles
# 33           21         Rua São Paulo    500          Centro
# 34           18     Trav. das Acacias     45  Jardim America
# 35           39                 Rua D     15          Centro
# 36           38                 Rua C    200          papicu
# 37           56         Rua Principal      1     industrial
# 38           51         Rua São Paulo    500          Centro
# 39           36                 Rua A    NaN         Aldeota
# 40           44   Rua Jose de Alencar     88         BENFICA
# 41           46          Rua sem nome    NaN          Centro
# 42           34          Av Beira Mar   2500        Meireles
# 43           33         Av. Beira Mar   2500       Meireles
# 44           54             Av Brasil    900          Centro
# 45           53            Av. Brasil    900          Centro
# 46           29     Rua das Palmeiras    340           Cocó
# 47           47  Travessa das Acácias     45  Jardim América
# 48           35                 Rua A     12         Aldeota
# 49            9                 Rua D     15          Centro
# 50            8                 Rua C    200          papicu
# 51           19      Rua Padre Cícero    150          Centro
# 52            5                 Rua A     12         Aldeota
# 53           13   Rua José de Alencar     88         Benfica
# 54            7                 Rua B    34A          Papicu
# 55           10                 Rua D     15          Centro
# 56           60     Rua das Palmeiras    340            Coco
# 57           31       Rua das Flores     101          Centro
# 58           16          Rua sem nome    NaN          Centro
# 59           52         Rua Sao Paulo    500          CENTRO
#
#                cidade estado        cep
# 0           Maracanaú     CE  61900-000
# 1           FORTALEZA     ce   60410300
# 2           FORTALEZA     CE   60150161
# 3            Caucaia      ce   61600000
# 4           fortaleza     CE   60165121
# 5           Horizonte     ce   62880000
# 6           FORTALEZA     ce   60010000
# 7           Fortaleza     CE        NaN
# 8           Fortaleza     CE  60192-150
# 9           Fortaleza     CE  60020-120
# 10          Horizonte     CE  62880-000
# 11          Fortaleza     CE  60150-161
# 12          Fortaleza     ce   60020120
# 13          FORTALEZA     CE        NaN
# 14          Horizonte     CE  62880-000
# 15            Quixadá     CE  63900-000
# 16          Fortaleza     CE
# 17            Quixada     CE   63900000
# 18          Fortaleza     CE  60410-300
# 19  Juazeiro do Norte     ce   63010020
# 20          Fortaleza     CE
# 21          Fortaleza     CE  60150-161
# 22          FORTALEZA     CE        NaN
# 23  Juazeiro do Norte     CE  63010-020
# 24          Fortaleza     ce   60192150
# 25          FORTALEZA     CE   60150161
# 26          FORTALEZA     ce   60010000
# 27  Juazeiro do Norte     ce   63010020
# 28          Fortaleza     CE  60150-100
# 29          Fortaleza     CE  60010-000
# 30          Maracanaú     CE  61900-000
# 31             Sobral     ce   62010001
# 32          Fortaleza  Ceará  60165-121
# 33             Sobral     CE  62010-001
# 34          FORTALEZA     ce   60410300
# 35            Caucaia     CE  61600-000
# 36          FORTALEZA     ce  60190-200
# 37          Horizonte     ce   62880000
# 38             Sobral     CE  62010-001
# 39          Fortaleza     CE  60150-100
# 40          Fortaleza     ce   60020120
# 41          Maracanau     CE        NaN
# 42          fortaleza     CE   60165121
# 43          Fortaleza  Ceará  60165-121
# 44            Quixada     CE   63900000
# 45            Quixadá     CE  63900-000
# 46          Fortaleza     CE  60192-150
# 47          Fortaleza     CE  60410-300
# 48          Fortaleza     CE  60150-100
# 49            Caucaia     CE  61600-000
# 50          FORTALEZA     ce  60190-200
# 51  Juazeiro do Norte     CE  63010-020
# 52          Fortaleza     CE  60150-100
# 53          Fortaleza     CE  60020-120
# 54          Fortaleza     CE        NaN
# 55           Caucaia      ce   61600000
# 56          Fortaleza     ce   60192150
# 57          Fortaleza     CE  60010-000
# 58          Maracanau     CE        NaN
# 59             Sobral     ce   62010001
